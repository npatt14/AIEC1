# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Ah, the age‑old tongue‑twister that has both baffled children and perplexed scientists for centuries! 🎵
# > **“How much wood would a woodchuck chuck if a woodchuck could chuck wood?”**
#
# ### The “Scientific” Take
# A 1988 study by wildlife biologist **Richard Thomas** was actually conducted on the *amount of dirt* a woodchuck (also known as a groundhog) could move when digging its burrow. While no actual wood‑chucking was observed, the study’s estimate of a single woodchuck moving **about 700 pounds (≈317 kg)** of material in 8 hours of digging was popularised and taken (a bit of a leap of imagination) as the answer to the tongue‑twister.
#
# Since wood and dirt differ in density, the “woodchuck‑wood” figure would likewise be in the **hundreds of pounds** range *if* such an animal could indeed chuck wood.
#
# ### Play‑by‑the-Rhyme Answer
# The classic rhyming reply goes:
#
# > “A woodchuck would “chuck” as much wood as a woodchuck could chuck,*
# >  if a woodchuck could chuck wood!”
#
# …and that’s pretty much all we can say about a chucking creature that prefers burrows to lumberyards.
#
# ### Bottom Line
# - **Real woodchucks** don’t chuck wood; they burrow in dirt.
# - Based on the dirt‑chucking estimate, *if* they could chuck wood, they’d probably move **~700 lb** of it—give or take.
# - The sentence itself remains a delightful linguistic puzzle rather than a zoological fact.
#
# So whether you’re reciting the rhyme to your kids or just enjoying the absurdity, remember: the true marvel is the way a simple question can bring out both humor and a dash of pseudo‑science! 🌲🐹

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 4: <|channel|>analysis<|message|>We need to respond in HTTP JSO...
# Response 16: A woodchuck would chuck wood as much as the folklore allows ...
# Response 2: A classic riddle! While wood‑chucks (aka groundhogs) don’t a...
# Response 13: The classic tongue‑twister goes:
#
# > **“How much wood would...
# Response 22: A classic riddle! The usual playful answer is:
#
# > **A woodch...
# Response 7: The classic tongue‑twister has a couple of “answers” dependi...
# Response 12: The old tongue‑twister turns out to have a rather practical ...
# Response 10: **Answer:**
# A woodchuck would chuck **about 7,000 pounds (...
# Response 15: **Answer to “Request 15” – How much wood could a wood‑chuck ...
# Response 24: In the spirit of the classic tongue‑twister, the most “scien...
# Response 6: **Answer**
#
# A wood‑chuck (ground‑hog) doesn’t actually “chuc...
# Response 8: A woodchuck would chuck as much wood as a woodchuck could if...
# Response 5: Sure thing! Here’s a classic‑style answer that captures the ...
# Response 1: The classic tongue‑twister has no single, scientifically‑ver...
# Response 14: Very funny—classic tongue‑twister! The “real” answer is that...
# Response 18: *A classic tongue‑twister that’s been passed down for genera...
# Response 17: 🎶 **“Hey, I’ve got a wood‑chuck… A wood‑chuck // would chuck...
# Response 20: A 1988 study by wildlife biologist Richard Thomas estimated ...
# Response 21: A woodchuck (also known as a groundhog) can't actually chuck...
# Response 23: **The classic “woodchuck” question is more tongue‑twister th...
# Response 3: It’s one of those classic “what‑if” questions that delights ...
# Response 19: It’s one of those classic “tongue‑twisters” that isn’t reall...
# Response 9: You’re asking the classic “tongue‑twister” question that’s b...
# Response 11: In short, the punchline is the classic tongue‑twister itself...
